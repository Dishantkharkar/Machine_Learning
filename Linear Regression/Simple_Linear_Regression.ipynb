# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('placement.csv')

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
plt.scatter(df['cgpa'],df['package'])
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
# split data into x and y
x = df.iloc[:,:1]
y = df.iloc[:,1:]

# %%
x
# Out:
#      cgpa
# 0    6.89
# 1    5.12
# 2    7.82
# 3    7.42
# 4    6.94
# ..    ...
# 195  6.93
# 196  5.89
# 197  7.21
# 198  7.63
# 199  6.22
#
# [200 rows x 1 columns]

# %%
y
# Out:
#      package
# 0       3.26
# 1       1.98
# 2       3.25
# 3       3.67
# 4       3.57
# ..       ...
# 195     2.46
# 196     2.57
# 197     3.24
# 198     3.96
# 199     2.33
#
# [200 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=3)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_test
# Out:
#      cgpa
# 40   9.38
# 51   9.26
# 139  7.19
# 197  7.21
# 170  6.22
# 82   5.58
# 183  7.28
# 46   6.07
# 70   5.79
# 100  7.95
# 179  7.14
# 83   8.44
# 25   7.28
# 190  6.19
# 159  8.71
# 173  6.75
# 95   6.63
# 3    7.42
# 41   6.89
# 58   6.92
# 14   7.73
# 143  4.85
# 12   8.94
# 6    6.73
# 182  5.88
# 161  7.30
# 128  7.93
# 122  5.12
# 101  6.71
# 86   7.61
# 64   7.36
# 47   5.84
# 158  5.95
# 34   7.34
# 38   8.62
# 196  5.89
# 4    6.94
# 72   7.78
# 67   6.51
# 145  5.84

# %%
y_test
# Out:
#      package
# 40      4.02
# 51      3.79
# 139     2.40
# 197     3.24
# 170     2.87
# 82      2.17
# 183     2.72
# 46      2.26
# 70      2.35
# 100     4.14
# 179     3.03
# 83      3.49
# 25      3.65
# 190     2.69
# 159     4.08
# 173     2.56
# 95      2.79
# 3       3.67
# 41      2.70
# 58      3.09
# 14      3.42
# 143     1.54
# 12      3.65
# 6       2.60
# 182     2.08
# 161     3.33
# 128     3.34
# 122     2.01
# 101     3.52
# 86      2.77
# 64      2.92
# 47      3.26
# 158     3.04
# 34      3.42
# 38      4.36
# 196     2.57
# 4       3.57
# 72      3.62
# 67      2.89
# 145     2.18

# %%
lr.predict(x_test.iloc[0].values.reshape(1,1))
# Out:
# c:\Users\disha\anaconda3\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[4.39751239]])

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(x_train,lr.predict(x_train),color='red')
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
m = lr.coef_  #slope

# %%
c = lr.intercept_

# %%
print(m)
print(c)
# Out:
# [[0.5892411]]
# [-1.12956915]

# %%
# y = mx+c

m*100+c
# Out:
# array([[57.79454102]])
